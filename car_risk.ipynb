# %%
# !unzip '/content/drive/MyDrive/archive (1).zip'
# Out:
# Archive:  /content/drive/MyDrive/archive (1).zip
#   inflating: car driving risk analysis.csv

# %%
import pandas as pd

df = pd.read_csv('/content/car driving risk analysis.csv')
df.head()
# Out:
#    speed  risk
# 0    200    95
# 1     90    20
# 2    300    98
# 3    110    60
# 4    240    72

# %%
df.isnull().sum()
# Out:
# speed    0
# risk     0
# dtype: int64

# %%
X = df[['speed']]
y = df['risk']

# %%
from sklearn.model_selection import train_test_split 

xtrain,xtest,ytrain,ytest = train_test_split(X,y,test_size=0.3,random_state=3)

from sklearn.linear_model import LinearRegression 
model = LinearRegression()

# %%
ytrain.shape
# Out:
# (6, 1)

# %%
xtrain
# Out:
#     speed
# 11    185
# 7     230
# 5     115
# 0     200
# 14     30
# 13     95
# 3     110
# 9     260
# 8     190
# 10    290

# %%
xtest
# Out:
#     speed
# 12    310
# 4     240
# 1      90
# 6      50
# 2     300

# %%
df
# Out:
#     speed  risk
# 0     200    95
# 1      90    20
# 2     300    98
# 3     110    60
# 4     240    72
# 5     115    10
# 6      50     7
# 7     230    85
# 8     190    45
# 9     260    91
# 10    290    82
# 11    185    59
# 12    310    93
# 13     95    18
# 14     30     2

# %%
regressor.fit(xtrain,ytrain)
regressor.score(xtrain,ytrain)
# Out:
# 0.7293060849274389

# %%
regressor.predict(xtest)
# Out:
# array([105.62697045,  80.07221825,  25.31203497,  10.70931943,
#        101.97629156])
